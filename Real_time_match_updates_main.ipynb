# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/live"

headers = {
	"x-rapidapi-key": "ea3505701bmshb507219d644246ap179011jsnf404491629d7",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'typeMatches': [{'matchType': 'Domestic', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 9360, 'seriesName': 'County Championship Division One 2025', 'matches': [{'matchInfo': {'matchId': 113289, 'seriesId': 9360, 'seriesName': 'County Championship Division One 2025', 'matchDesc': '70th Match', 'matchFormat': 'TEST', 'startDate': '1758706200000', 'endDate': '1758990600000', 'state': 'In Progress', 'status': 'Day 4: 2nd Session - Durham trail by 55 runs', 'team1': {'teamId': 141, 'teamName': 'Durham', 'teamSName': 'DUR', 'imageId': 172208}, 'team2': {'teamId': 146, 'teamName': 'Yorkshire', 'teamSName': 'YORKS', 'imageId': 172213}, 'venueInfo': {'id': 66, 'ground': 'Headingley', 'city': 'Leeds', 'timezone': '+01:00', 'latitude': '53.817622', 'longitude': '-1.58211'}, 'currBatTeamId': 141, 'seriesStartDt': '1743724800000', 'seriesEndDt': '1759104000000', 'isTimeAnnounced': True, 'stateTitle': 'In Progress'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 346, 'wic
# ...

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/recent"

headers = {
	"x-rapidapi-key": "ea3505701bmshb507219d644246ap179011jsnf404491629d7",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 10587, 'seriesName': 'Asia Cup 2025', 'matches': [{'matchInfo': {'matchId': 130168, 'seriesId': 10587, 'seriesName': 'Asia Cup 2025', 'matchDesc': 'Super Fours, 18th Match (A1 v B1)', 'matchFormat': 'T20', 'startDate': '1758897000000', 'endDate': '1758909600000', 'state': 'Complete', 'status': 'Match tied (India Won the Super Over)', 'team1': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 719031}, 'team2': {'teamId': 5, 'teamName': 'Sri Lanka', 'teamSName': 'SL', 'imageId': 172119}, 'venueInfo': {'id': 153, 'ground': 'Dubai International Cricket Stadium', 'city': 'Dubai', 'timezone': '+04:00', 'latitude': '25.046842', 'longitude': '55.218969'}, 'seriesStartDt': '1757376000000', 'seriesEndDt': '1759190400000', 'isTimeAnnounced': True, 'stateTitle': 'Complete'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 202, 'wickets': 5, 'overs': 19.6}}, 'team2Sc
# ...

# %%
data = response.json()

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
print(data.keys())
# Out:
# dict_keys(['typeMatches', 'filters', 'appIndex', 'responseLastUpdated', 'contentFilters'])

# %%
data['filters']
# Out:
# {'matchType': ['International', 'League', 'Domestic', 'Women']}

# %%
data['responseLastUpdated']
# Out:
# '1758979412'

# %%
data['appIndex']
# Out:
# {'seoTitle': 'Live Cricket Score - Scorecard and Match Results',
#  'webURL': 'www.cricbuzz.com/live-cricket-scores/'}

# %%
data['typeMatches']
# Out:
# [{'matchType': 'International',
#   'seriesMatches': [{'seriesAdWrapper': {'seriesId': 10587,
#      'seriesName': 'Asia Cup 2025',
#      'matches': [{'matchInfo': {'matchId': 130168,
#         'seriesId': 10587,
#         'seriesName': 'Asia Cup 2025',
#         'matchDesc': 'Super Fours, 18th Match (A1 v B1)',
#         'matchFormat': 'T20',
#         'startDate': '1758897000000',
#         'endDate': '1758909600000',
#         'state': 'Complete',
#         'status': 'Match tied (India Won the Super Over)',
#         'team1': {'teamId': 2,
#          'teamName': 'India',
#          'teamSName': 'IND',
#          'imageId': 719031},
#         'team2': {'teamId': 5,
#          'teamName': 'Sri Lanka',
#          'teamSName': 'SL',
#          'imageId': 172119},
#         'venueInfo': {'id': 153,
#          'ground': 'Dubai International Cricket Stadium',
#          'city': 'Dubai',
#          'timezone': '+04:00',
#          'latitude': '25.046842',
# ...

# %%
type_matches = data['typeMatches']
print(type_matches[0])
# Out:
# {'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 10587, 'seriesName': 'Asia Cup 2025', 'matches': [{'matchInfo': {'matchId': 130168, 'seriesId': 10587, 'seriesName': 'Asia Cup 2025', 'matchDesc': 'Super Fours, 18th Match (A1 v B1)', 'matchFormat': 'T20', 'startDate': '1758897000000', 'endDate': '1758909600000', 'state': 'Complete', 'status': 'Match tied (India Won the Super Over)', 'team1': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 719031}, 'team2': {'teamId': 5, 'teamName': 'Sri Lanka', 'teamSName': 'SL', 'imageId': 172119}, 'venueInfo': {'id': 153, 'ground': 'Dubai International Cricket Stadium', 'city': 'Dubai', 'timezone': '+04:00', 'latitude': '25.046842', 'longitude': '55.218969'}, 'seriesStartDt': '1757376000000', 'seriesEndDt': '1759190400000', 'isTimeAnnounced': True, 'stateTitle': 'Complete'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 202, 'wickets': 5, 'overs': 19.6}}, 'team2Score': {'inngs1': 
# ...

# %%
type_matches[0].keys()
# Out:
# dict_keys(['matchType', 'seriesMatches'])

# %%
type_matches[0]['matchType']
# Out:
# 'International'

# %%
type_matches[0]['seriesMatches']
# Out:
# [{'seriesAdWrapper': {'seriesId': 10587,
#    'seriesName': 'Asia Cup 2025',
#    'matches': [{'matchInfo': {'matchId': 130168,
#       'seriesId': 10587,
#       'seriesName': 'Asia Cup 2025',
#       'matchDesc': 'Super Fours, 18th Match (A1 v B1)',
#       'matchFormat': 'T20',
#       'startDate': '1758897000000',
#       'endDate': '1758909600000',
#       'state': 'Complete',
#       'status': 'Match tied (India Won the Super Over)',
#       'team1': {'teamId': 2,
#        'teamName': 'India',
#        'teamSName': 'IND',
#        'imageId': 719031},
#       'team2': {'teamId': 5,
#        'teamName': 'Sri Lanka',
#        'teamSName': 'SL',
#        'imageId': 172119},
#       'venueInfo': {'id': 153,
#        'ground': 'Dubai International Cricket Stadium',
#        'city': 'Dubai',
#        'timezone': '+04:00',
#        'latitude': '25.046842',
#        'longitude': '55.218969'},
#       'seriesStartDt': '1757376000000',
#       'seriesEndDt': '1759190400000',
# ...

# %%
series_matches = type_matches[0]['seriesMatches']
print(series_matches[0])
# Out:
# {'seriesAdWrapper': {'seriesId': 10587, 'seriesName': 'Asia Cup 2025', 'matches': [{'matchInfo': {'matchId': 130168, 'seriesId': 10587, 'seriesName': 'Asia Cup 2025', 'matchDesc': 'Super Fours, 18th Match (A1 v B1)', 'matchFormat': 'T20', 'startDate': '1758897000000', 'endDate': '1758909600000', 'state': 'Complete', 'status': 'Match tied (India Won the Super Over)', 'team1': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 719031}, 'team2': {'teamId': 5, 'teamName': 'Sri Lanka', 'teamSName': 'SL', 'imageId': 172119}, 'venueInfo': {'id': 153, 'ground': 'Dubai International Cricket Stadium', 'city': 'Dubai', 'timezone': '+04:00', 'latitude': '25.046842', 'longitude': '55.218969'}, 'seriesStartDt': '1757376000000', 'seriesEndDt': '1759190400000', 'isTimeAnnounced': True, 'stateTitle': 'Complete'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 202, 'wickets': 5, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId': 2, 'runs': 202, 'wickets': 5, 'over
# ...

# %%
series_matches[0].keys()
# Out:
# dict_keys(['seriesAdWrapper'])

# %%
series_matches[0]['seriesAdWrapper']
# Out:
# {'seriesId': 10587,
#  'seriesName': 'Asia Cup 2025',
#  'matches': [{'matchInfo': {'matchId': 130168,
#     'seriesId': 10587,
#     'seriesName': 'Asia Cup 2025',
#     'matchDesc': 'Super Fours, 18th Match (A1 v B1)',
#     'matchFormat': 'T20',
#     'startDate': '1758897000000',
#     'endDate': '1758909600000',
#     'state': 'Complete',
#     'status': 'Match tied (India Won the Super Over)',
#     'team1': {'teamId': 2,
#      'teamName': 'India',
#      'teamSName': 'IND',
#      'imageId': 719031},
#     'team2': {'teamId': 5,
#      'teamName': 'Sri Lanka',
#      'teamSName': 'SL',
#      'imageId': 172119},
#     'venueInfo': {'id': 153,
#      'ground': 'Dubai International Cricket Stadium',
#      'city': 'Dubai',
#      'timezone': '+04:00',
#      'latitude': '25.046842',
#      'longitude': '55.218969'},
#     'seriesStartDt': '1757376000000',
#     'seriesEndDt': '1759190400000',
#     'isTimeAnnounced': True,
#     'stateTitle': 'Complete'},
# ...

# %%
series_AdWrapper = series_matches[0]['seriesAdWrapper']

# %%
print (series_AdWrapper)
# Out:
# {'seriesId': 10587, 'seriesName': 'Asia Cup 2025', 'matches': [{'matchInfo': {'matchId': 130168, 'seriesId': 10587, 'seriesName': 'Asia Cup 2025', 'matchDesc': 'Super Fours, 18th Match (A1 v B1)', 'matchFormat': 'T20', 'startDate': '1758897000000', 'endDate': '1758909600000', 'state': 'Complete', 'status': 'Match tied (India Won the Super Over)', 'team1': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 719031}, 'team2': {'teamId': 5, 'teamName': 'Sri Lanka', 'teamSName': 'SL', 'imageId': 172119}, 'venueInfo': {'id': 153, 'ground': 'Dubai International Cricket Stadium', 'city': 'Dubai', 'timezone': '+04:00', 'latitude': '25.046842', 'longitude': '55.218969'}, 'seriesStartDt': '1757376000000', 'seriesEndDt': '1759190400000', 'isTimeAnnounced': True, 'stateTitle': 'Complete'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 202, 'wickets': 5, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId': 2, 'runs': 202, 'wickets': 5, 'overs': 19.6}}}}, {'matc
# ...

# %%
series_AdWrapper.keys()
# Out:
# dict_keys(['seriesId', 'seriesName', 'matches'])

# %%
series_AdWrapper['matches']
# Out:
# [{'matchInfo': {'matchId': 130168,
#    'seriesId': 10587,
#    'seriesName': 'Asia Cup 2025',
#    'matchDesc': 'Super Fours, 18th Match (A1 v B1)',
#    'matchFormat': 'T20',
#    'startDate': '1758897000000',
#    'endDate': '1758909600000',
#    'state': 'Complete',
#    'status': 'Match tied (India Won the Super Over)',
#    'team1': {'teamId': 2,
#     'teamName': 'India',
#     'teamSName': 'IND',
#     'imageId': 719031},
#    'team2': {'teamId': 5,
#     'teamName': 'Sri Lanka',
#     'teamSName': 'SL',
#     'imageId': 172119},
#    'venueInfo': {'id': 153,
#     'ground': 'Dubai International Cricket Stadium',
#     'city': 'Dubai',
#     'timezone': '+04:00',
#     'latitude': '25.046842',
#     'longitude': '55.218969'},
#    'seriesStartDt': '1757376000000',
#    'seriesEndDt': '1759190400000',
#    'isTimeAnnounced': True,
#    'stateTitle': 'Complete'},
#   'matchScore': {'team1Score': {'inngs1': {'inningsId': 1,
#      'runs': 202,
#      'wickets': 5,
# ...

# %%
matches = series_AdWrapper['matches']

# %%
print(matches)
# Out:
# [{'matchInfo': {'matchId': 130168, 'seriesId': 10587, 'seriesName': 'Asia Cup 2025', 'matchDesc': 'Super Fours, 18th Match (A1 v B1)', 'matchFormat': 'T20', 'startDate': '1758897000000', 'endDate': '1758909600000', 'state': 'Complete', 'status': 'Match tied (India Won the Super Over)', 'team1': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 719031}, 'team2': {'teamId': 5, 'teamName': 'Sri Lanka', 'teamSName': 'SL', 'imageId': 172119}, 'venueInfo': {'id': 153, 'ground': 'Dubai International Cricket Stadium', 'city': 'Dubai', 'timezone': '+04:00', 'latitude': '25.046842', 'longitude': '55.218969'}, 'seriesStartDt': '1757376000000', 'seriesEndDt': '1759190400000', 'isTimeAnnounced': True, 'stateTitle': 'Complete'}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 202, 'wickets': 5, 'overs': 19.6}}, 'team2Score': {'inngs1': {'inningsId': 2, 'runs': 202, 'wickets': 5, 'overs': 19.6}}}}, {'matchInfo': {'matchId': 130124, 'seriesId': 10587, 'seriesName': '
# ...

# %%
matches[0].keys()
# Out:
# dict_keys(['matchInfo', 'matchScore'])

# %%
matches[0]['matchInfo']
# Out:
# {'matchId': 130168,
#  'seriesId': 10587,
#  'seriesName': 'Asia Cup 2025',
#  'matchDesc': 'Super Fours, 18th Match (A1 v B1)',
#  'matchFormat': 'T20',
#  'startDate': '1758897000000',
#  'endDate': '1758909600000',
#  'state': 'Complete',
#  'status': 'Match tied (India Won the Super Over)',
#  'team1': {'teamId': 2,
#   'teamName': 'India',
#   'teamSName': 'IND',
#   'imageId': 719031},
#  'team2': {'teamId': 5,
#   'teamName': 'Sri Lanka',
#   'teamSName': 'SL',
#   'imageId': 172119},
#  'venueInfo': {'id': 153,
#   'ground': 'Dubai International Cricket Stadium',
#   'city': 'Dubai',
#   'timezone': '+04:00',
#   'latitude': '25.046842',
#   'longitude': '55.218969'},
#  'seriesStartDt': '1757376000000',
#  'seriesEndDt': '1759190400000',
#  'isTimeAnnounced': True,
#  'stateTitle': 'Complete'}

# %%
Matchinfo = matches[0]['matchInfo']

# %%
print("Series Name:",Matchinfo['seriesName'])
print("Match Name:",Matchinfo['matchDesc'])
print("Venue:",Matchinfo['venueInfo']['ground'])
print("Team 1:",Matchinfo['team1']['teamName'])
print("Team 2:",Matchinfo['team2']['teamName'])
print("Result:",Matchinfo['status'])
# Out:
# Series Name: Asia Cup 2025
# Match Name: Super Fours, 18th Match (A1 v B1)
# Venue: Dubai International Cricket Stadium
# Team 1: India
# Team 2: Sri Lanka
# Result: Match tied (India Won the Super Over)

# %%
matches = []

for type_match in data.get("typeMatches", []):
	for series_match in type_match.get("seriesMatches", []):
        series_data = series_match.get("seriesAdWrapper", {})
        series_id = series_data.get("seriesId")
	
    	for match in series_data.get("matches",[]):
        	info = match.get("matchInfo",{})
        	match_desc = info.get("matchDesc")
        	status = info.get("status")
        	team1 = info.get("team1",{}).get("teamName")
        	team2 = info.get("team2",{}).get("teamName")
        	venue = info.get("venueInfo",{}).get("ground")
	
        	matches.append({
        		"Description": match_desc,
        		"status": status,
        		"team1": team1,
        		"team2": team2,
        		"venue": venue
        	})
# Out:
# Traceback (most recent call last):
#   File "/lib/python3.12/site-packages/pyodide_kernel/kernel.py", line 104, in run
#     code = await self.lite_transform_manager.transform_cell(code)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/lib/python3.12/site-packages/pyodide_kernel/litetransform.py", line 34, in transform_cell
#     lines = await self.do_token_transforms(lines)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/lib/python3.12/site-packages/pyodide_kernel/litetransform.py", line 39, in do_token_transforms
#     changed, lines = await self.do_one_token_transform(lines)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/lib/python3.12/site-packages/pyodide_kernel/litetransform.py", line 59, in do_one_token_transform
#     tokens_by_line = make_tokens_by_line(lines)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
